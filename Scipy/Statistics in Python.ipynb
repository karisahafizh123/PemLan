# %% [markdown]
# # 3.1.1

# %%
import pandas as pd
import numpy as np

# %%
import urllib.request
url = 'http://scipy-lectures.org/_downloads/brain_size.csv'
urllib.request.urlretrieve(url, 'brain_size.csv')
data = pd.read_csv('brain_size.csv', sep=';',na_values=".")
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# ...

# %%
t = np.linspace(-6, 6, 20)
sin_t = np.sin(t)
cos_t = np.cos(t)

# %%
pd.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %%
data.shape
# Out:
# (40, 8)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %%
print(data['Gender'])
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# 109.45

# %%
data.describe()
# Out:
#        Unnamed: 0        FSIQ         VIQ        PIQ      Weight     Height  \
# count   40.000000   40.000000   40.000000   40.00000   38.000000  39.000000
# mean    20.500000  113.450000  112.350000  111.02500  151.052632  68.525641
# std     11.690452   24.082071   23.616107   22.47105   23.478509   3.994649
# min      1.000000   77.000000   71.000000   72.00000  106.000000  62.000000
# 25%     10.750000   89.750000   90.000000   88.25000  135.250000  66.000000
# 50%     20.500000  116.500000  113.000000  115.00000  146.500000  68.000000
# 75%     30.250000  135.500000  129.750000  128.00000  172.000000  70.500000
# max     40.000000  144.000000  150.000000  150.00000  192.000000  77.000000
#
#           MRI_Count
# count  4.000000e+01
# mean   9.087550e+05
# std    7.228205e+04
# min    7.906190e+05
# 25%    8.559185e+05
# 50%    9.053990e+05
# 75%    9.500780e+05
# max    1.079549e+06

# %%
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', 109.45)
# ('Male', 115.25)

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %%
#Exercise
#What is the mean value for VIQ for the full population?
data['VIQ'].mean()
# Out:
# 112.35

# %%
#Exercise
#How many males/females were included in this study?
#Hint use ‘tab completion’ to find out the methods that can be called, instead of ‘mean’ in the above example.
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.count()))
# Out:
# ('Female', 20)
# ('Male', 20)

# %%
#Exercise
#What is the average value of MRI counts expressed in log units, for males and females?
import math 
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['MRI_Count']:
    print((gender, math.log(value.mean(), 10)))
# Out:
# ('Female', 5.935836942481714)
# ('Male', 5.979937608508486)

# %% [markdown]
# #### Note: pandas version 0.25.2, python version 3.7.4
# Package pandas.tools.plotting was moved to pandas.plotting in Pandas 0.20.0.
# In Pandas 0.24.0, the deprecated pandas.tools package,
# which was previously allowing pandas.tools.plotting to keep working, was removed.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CC7DCCEC8>,
# ...
#       dtype=object)

# %%
scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CC84C1888>,
# ...
#       dtype=object)

# %%
#Exercise
#Plot the scatter matrix for males only(a)
scatter_matrix(data[data.Gender == 'Male'][['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CC8A0F848>,
# ...
#       dtype=object)

# %%
#Exercise
#Plot the scatter matrix for males only(b)
scatter_matrix(data[data.Gender == 'Male'][['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CC8BE6FC8>,
# ...
#       dtype=object)

# %%
#Exercise
#Plot the scatter matrix for females only(a)
scatter_matrix(data[data.Gender == 'Female'][['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CC9F9C788>,
# ...
#       dtype=object)

# %%
#Exercise
#Plot the scatter matrix for females only(b)
scatter_matrix(data[data.Gender == 'Female'][['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CC9F8E3C8>,
# ...
#       dtype=object)

# %% [markdown]
# # 3.1.3.1

# %%
import numpy as np
x = np.linspace(-5, 5, 20)
np.random.seed(1)
# normal distributed noise
y = -5 + 3*x + 4 * np.random.normal(size=x.shape)
# Create a data frame containing all the relevant variables
data1 = pd.DataFrame({'x': x, 'y': y})
data1
# Out:
#            x          y
# 0  -5.000000 -13.502619
# 1  -4.473684 -20.868078
# 2  -3.947368 -18.954792
# 3  -3.421053 -19.555032
# 4  -2.894737 -10.222580
# 5  -2.368421 -21.311418
# 6  -1.842105  -3.547069
# 7  -1.315789 -11.992196
# 8  -0.789474  -6.092265
# 9  -0.263158  -6.786955
# 10  0.263158   1.637905
# 11  0.789474 -10.872142
# 12  1.315789  -2.342300
# 13  1.842105  -1.009902
# 14  2.368421   6.640341
# 15  2.894737  -0.715355
# 16  3.421053   4.573445
# 17  3.947368   3.330672
# 18  4.473684   8.589908
# 19  5.000000  12.331261

# %%
from statsmodels.formula.api import ols
model = ols("y ~ x", data1).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):           8.56e-08
# Time:                        01:15:48   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# ...

# %%
#Exercise
#Retrieve the estimated parameters from the model above.
model.params
# Out:
# Intercept   -5.533459
# x            2.936888
# dtype: float64

# %%
data = pd.read_csv('brain_size.csv', sep=';',na_values=".")
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# ...

# %%
model = ols("VIQ ~ Gender + 1", data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):              0.445
# Time:                        01:15:48   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        109.4500      5.308     20.619      0.000      98.704     120.196
# ...

# %%
model = ols('VIQ ~ C(Gender)', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):              0.445
# Time:                        01:15:48   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           109.4500      5.308     20.619      0.000      98.704     120.196
# ...

# %%
data_fisq = pd.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pd.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pd.concat((data_fisq, data_piq))
print(data_long)
# Out:
#      iq  type
# 0   133  fsiq
# 1   140  fsiq
# 2   139  fsiq
# 3   133  fsiq
# 4   137  fsiq
# ..  ...   ...
# 35  128   piq
# 36  124   piq
# 37   94   piq
# 38   74   piq
# 39   89   piq
#
# [80 rows x 2 columns]

# %%
model = ols("iq ~ type", data_long).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     iq   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2168
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):              0.643
# Time:                        01:15:48   Log-Likelihood:                -364.35
# No. Observations:                  80   AIC:                             732.7
# Df Residuals:                      78   BIC:                             737.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     113.4500      3.683     30.807      0.000     106.119     120.781
# ...

# %%
from scipy import stats
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# Ttest_indResult(statistic=0.465637596380964, pvalue=0.6427725009414841)

# %% [markdown]
# # 3.1.3.2

# %%
url = 'http://scipy-lectures.org/_downloads/iris.csv'
urllib.request.urlretrieve(url, 'iris.csv')
data2 = pd.read_csv('iris.csv', sep=',',na_values=".")
data2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       name
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
model = ols('sepal_width ~ name + petal_length', data2).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):           1.58e-20
# Time:                        01:15:49   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# ...

# %% [markdown]
# # 3.1.3.3

# %%
print(model.f_test([0, 1, -1, 0]))
# Out:
# <F test: F=array([[3.24533535]]), p=0.07369058781700738, df_denom=146, df_num=1>
